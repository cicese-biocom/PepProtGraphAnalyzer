# %% [markdown]
# # **Inter-Amino Acid Distance Distribution Analysis**

# %% [markdown]
# **Dataset: StarPep (sequences from 10 to 100 amino acids)**

# %%
import pandas as pd
from plot import plot_inter_amino_acid_distances

base_path = 'data/StarPep/Analysis-2024-06-14T14.51.48/Graph_Analysis/'
# Out:
# /tmp/ipykernel_50120/3121194850.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## **Angular separation**

# %%
distance_function = 'angular_separation'
x_axis_step = 0.2 
binwidth = 0.012

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Bhattacharyya**

# %%
distance_function = 'bhattacharyya'
x_axis_step = 2
binwidth = 0.22

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Canberra**

# %%
distance_function = 'canberra'
x_axis_step = 0.5
binwidth = 0.04

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Clark**

# %%
distance_function = 'clark'
x_axis_step = 0.5
binwidth = 0.025

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Euclidean**

# %%
distance_function = 'euclidean'
x_axis_step = 20
binwidth = 3.2

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Lance Williams**

# %%
distance_function = 'lance_williams'
x_axis_step = 0.2
binwidth = 0.015

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)

# %% [markdown]
# ## **Soergel**

# %%
distance_function = 'soergel'
x_axis_step = 0.2
binwidth = 0.015

distances_filepath = f'{base_path}Inter_Amino_Acid_Distances-{distance_function}.csv'
output_filepath = f'output/StarPep/Inter_Amino_Acid_Distances-{distance_function}.png'
plot_inter_amino_acid_distances(distances_filepath, distance_function, x_axis_step, binwidth, output_filepath)
