# %% [markdown]
# # Analysis of Amino Acid Composition

# %% [markdown]
# **Dataset: StarPep (sequences from 10 to 100 amino acids)**

# %%
from utils.plotting import bar_chart
import pandas as pd
import numpy as np

# %%
# paths
base_path = '../output/StarPep/PaperNew/2024-12-23T15.40.45-Data_Ingestion/Analysis/'
output_path = './output/graphics/'

# load Sequence-Amino_Acid_Composition csv
amino_acid_composition = pd.read_csv(base_path + 'Sequence-Amino_Acid_Composition.csv')

# %%
plt = bar_chart(amino_acid_composition, 'code_large', 'count', x_label='Amino Acids', y_label='Frecuency', output=f'{output_path}bar_chart-amino_acid_composition', fig_size=(8, 4))
plt.show()
