# %%
import sys
import os
from pathlib import Path

# %%
# Agregar la ruta principal al sys.path
sys.path.append('/home/jovyan/work/algorithms4pepprotgraphs')

# %%
from algorithms4pepprotgraphs.module.notebook import DBClient

dataset_path = Path("algorithms4pepprotgraphs/dataset/AVPDiscover/AVPDiscover.csv").resolve()
output_path = Path("output").resolve()

db = DBClient(dataset_path, output_path)

# %%
result = db.get_sequences_with_max_distance('euclidean')

# %%
result.head()
# Out:
#                                             sequence  aa_src  aa_dst  aa_src  \
# 0  SRSGRGSGKGGRGGSRGSSGSRGSKGPSGSRGSSGSRGSKGSRGGR...       0      66       0
#
#     euclidean  canberra  lance_williams     clark  soergel  bhattacharyya  \
# 0  194.841435       3.0             1.0  1.732051      1.0      17.437551
#
#    angular_separation
# 0            0.098817
