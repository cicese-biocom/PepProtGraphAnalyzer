# %% [markdown]
# # **Sequence Amino Acid Composition**

# %% [markdown]
# ## 📦 **Package Import**

# %%
# python
import pandas as pd
import numpy as np
from IPython.display import display, Markdown
import sys
import os
from pathlib import Path

# algorithms4pepprotgraphs framework
sys.path.append('/home/jovyan/work/PepProtGraphAnalyzer')
from PepProtGraphAnalyzer.module.notebook import NotebookApp
from PepProtGraphAnalyzer.util.plotting import bar_chart

app = NotebookApp('.env.jupyter.AVPExternal')
paths = app.paths()
# Out:
# [2025-09-23 19:40:55,362] WARNING [data_validator.py:87] Sequences with non-natural amino acids were excluded. See: /home/jovyan/work/output/out_paper/AVP-external/Log/Sequences with Non-Natural Amino Acids.csv
# [2025-09-23 19:41:12,770] INFO [notebook.py:70] Setting:
# dataset_path: /home/jovyan/work/PepProtGraphAnalyzer/dataset/AVPDiscover/AVP-external.csv
# pdb_path: /home/jovyan/work/PepProtGraphAnalyzer/dataset/AVPDiscover/ESMFold_pdbs
# notebook_output_path: /home/jovyan/work/output/out_paper/AVP-external
# sequence_analysis_path: /home/jovyan/work/PepProtGraphAnalyzer/output/results_with_seq_10_to_100/AVPExternal/2025-04-07T19.52.26-Sequence_Analyzer
# graph_analysis_path: /home/jovyan/work/PepProtGraphAnalyzer/output/results_with_seq_10_to_100/AVPExternal/2025-04-07T21.26.46-Graph_Analyzer
# min_seq_len: 10
# max_seq_len: 100

# %% [markdown]
# ## 📊 **Data Analysis**

# %% [markdown]
# ### **Amino Acid Composition Data**

# %%
amino_acid_composition = pd.read_csv(app.sequence_analysis['sequence_amino_acid_composition'])
amino_acid_composition
# Out:
#    code_short code_large  count
# 0           A        ALA  57062
# 1           R        ARG  49336
# 2           N        ASN  30687
# 3           D        ASP  34392
# 4           C        CYS  14632
# 5           Q        GLN  28028
# 6           E        GLU  51564
# 7           G        GLY  49544
# 8           H        HIS  14568
# 9           I        ILE  52681
# 10          L        LEU  79015
# 11          K        LYS  58975
# 12          M        MET  28103
# 13          F        PHE  33291
# 14          P        PRO  31418
# 15          S        SER  49276
# 16          T        THR  43423
# 17          W        TRP   7584
# 18          Y        TYR  21201
# 19          V        VAL  56830

# %% [markdown]
# ### **Analysis of Amino Acid Composition**

# %%
output = paths['amino_acid_composition_path'].joinpath("Amino Acid Composition (barchart)")
plt = bar_chart(amino_acid_composition, 'code_large', 'count', x_label='Amino Acids', y_label='Frecuency', output=output, fig_size=(8, 4))
plt.show()
